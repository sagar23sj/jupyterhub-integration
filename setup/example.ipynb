# %%
# Set the env vars accrodingly before running the test
# %set_env DP_PASSWORD = example_password_string
# %set_env DISTRIBUTED_EXECUTION = true
# %set_env PARTITION_PRUNING = true
# %set_env USE_NEW_METASTORE_API = false
# %run setup.py

# %%
df = %dpsql select * from testglue.dpe2e.car_data
display(df)
# Out:
# (rows, columns): (13, 7) | Execution Time: 1.79438 seconds
#         country   company    model   tax  quantity     price        date
# 0         India      Tata   Safari   5.0        10   1000000  2005-02-01
# 1       Germany     Skoda    Rapid   5.2         5   1500000  2005-01-01
# 2       Germany      Benz      GLC   8.5         3  10000000  2006-02-02
# 3       Germany     Skoda   Kushiq 10.11         9   6000000  2005-01-02
# 4       Germany      Audi       A4  12.5         4   7000000  2005-02-01
# 5       Germany      Audi       Q7  13.0         3   2000000  2006-01-01
# 6   South Korea   Hyundai    Creta   8.7         7   1800000  2005-01-02
# 7         India  Mahindra     Thar   2.0         6   1400000  2005-02-01
# 8       Germany      Benz  A-Class   6.2         5    700000  2006-01-01
# 9         India      Tata    Nexon   7.1         8    900000  2005-01-02
# 10      Germany      Audi       s5   3.0         2    900000  2006-02-02
# 11  South Korea   Hyundai      i20  12.5         1   3100000  2005-02-01
# 12        India  Mahindra  Scorpio   5.0         4   1200000  2005-02-02

# %%
dd = select_visualize_formats(df)
# Out:
# interactive(children=(Dropdown(description='Visualization: ', options=('Bar', 'Pie', 'Line', 'BarH'), value=No…

# %%
display(draw(dd))
# Out:
# <Axes: xlabel='country'>

# %%
dd1 = select_visualize_formats(df)
# Out:
# interactive(children=(Dropdown(description='Visualization: ', options=('Bar', 'Pie', 'Line', 'BarH'), value=No…

# %%
display(draw(dd1))
# Out:
# <Axes: ylabel='country'>

# %%
dd2 = select_visualize_formats(df)
# Out:
# interactive(children=(Dropdown(description='Visualization: ', options=('Bar', 'Pie', 'Line', 'BarH'), value=No…

# %%
display(draw(dd2))
# Out:
# array([<Axes: ylabel='country'>], dtype=object)

# %%
dd4 = select_visualize_formats(df)
# Out:
# interactive(children=(Dropdown(description='Visualization: ', options=('Bar', 'Pie', 'Line', 'BarH'), value=No…

# %%
display(draw(dd4))
# Out:
# <Axes: xlabel='model'>
